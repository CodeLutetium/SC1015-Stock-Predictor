# %% [markdown]
# # Stock prices forecasting with LSTM
# ## 1. Import libraries

# %%
import numpy as np
import pandas as pd

import os
import matplotlib.pyplot as plt
import datetime as dt
import plotly.graph_objects as go


from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Stock apis
from polygon import RESTClient

import constants as c
# Out:
# 2023-03-14 10:07:48.309749: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 2. Preprocessing

# %%
# Get data from api
client = RESTClient(api_key=c.POLY_APIKEY)
ticker = "AAPL"

# List Aggregates (Bars)
bars = client.get_aggs(ticker=ticker, multiplier=1, timespan="day", from_="2022-03-01", to="2023-03-31")
df = pd.DataFrame(bars)
df['date'] = pd.to_datetime(df['timestamp'], unit='ms')
df['change'] = df['close'] - df['open']
# df

fig = go.Figure(data=[go.Candlestick(x=df['date'],
                open=df['open'],
                high=df['high'],
                low=df['low'],
                close=df['close'])])

fig.show()

df
# Out:
#         open      high       low   close      volume      vwap      timestamp  \
# 0    164.695  166.6000  161.9700  163.20  83468865.0  164.1600  1646110800000
# 1    164.390  167.3600  162.9500  166.56  79724750.0  165.8095  1646197200000
# 2    168.470  168.9100  165.5500  166.23  76678441.0  166.9180  1646283600000
# 3    164.490  165.5500  162.1000  163.17  83819592.0  163.3980  1646370000000
# 4    163.360  165.0200  159.0400  159.30  96418845.0  161.4026  1646629200000
# ..       ...       ...       ...     ...         ...       ...            ...
# 254  153.785  156.3000  153.4600  153.83  87558028.0  154.6895  1678078800000
# 255  153.700  154.0299  151.1300  151.60  56136378.0  152.2768  1678165200000
# 256  152.810  153.4700  151.8300  152.87  47204791.0  152.6973  1678251600000
# 257  153.559  154.5350  150.2250  150.59  53833122.0  152.4689  1678338000000
# 258  150.210  150.9400  147.6096  148.50  68559600.0  149.0716  1678424400000
#
#      transactions   otc                date  change
# 0          749653  None 2022-03-01 05:00:00  -1.495
# 1          668260  None 2022-03-02 05:00:00   2.170
# 2          651764  None 2022-03-03 05:00:00  -2.240
# 3          743696  None 2022-03-04 05:00:00  -1.320
# 4          847057  None 2022-03-07 05:00:00  -4.060
# ..            ...   ...                 ...     ...
# 254        691990  None 2023-03-06 05:00:00   0.045
# 255        496631  None 2023-03-07 05:00:00  -2.100
# 256        405203  None 2023-03-08 05:00:00   0.060
# 257        480909  None 2023-03-09 05:00:00  -2.969
# 258        611457  None 2023-03-10 05:00:00  -1.710
#
# [259 rows x 11 columns]

# %%
# Drop all columns except for closing price and date (index)
close_df = df[['date', 'close']].set_index('date')
close_df
# Out:
#                       close
# date
# 2022-03-01 05:00:00  163.20
# 2022-03-02 05:00:00  166.56
# 2022-03-03 05:00:00  166.23
# 2022-03-04 05:00:00  163.17
# 2022-03-07 05:00:00  159.30
# ...                     ...
# 2023-03-06 05:00:00  153.83
# 2023-03-07 05:00:00  151.60
# 2023-03-08 05:00:00  152.87
# 2023-03-09 05:00:00  150.59
# 2023-03-10 05:00:00  148.50
#
# [259 rows x 1 columns]

# %%
# Prepare training set
train_df = close_df['2022-03-01':'2022-12-30']

# Normalise data
scaler = MinMaxScaler(feature_range=(0,1))      # Explore using StandardScaler instead of MinMaxScaler in the future
scaled_data = scaler.fit_transform(train_df['close'].values.reshape(-1,1))

# Number of days to base prediction on:
N_PRED_DAYS = 50

x_train, y_train = [], []

for i in range(len(scaled_data) - N_PRED_DAYS):
    x_train.append(scaled_data[i:i+N_PRED_DAYS, 0])
    y_train.append(scaled_data[i+N_PRED_DAYS, 0])


x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

x_train, y_train
# Out:
# (array([[[0.70219199],
#          [0.76568405],
#          [0.75944822],
#          ...,
#          [0.59032502],
#          [0.49168556],
#          [0.53798186]],
#
#         [[0.76568405],
#          [0.75944822],
#          [0.70162509],
#          ...,
#          [0.49168556],
#          [0.53798186],
#          [0.38662132]],
#
#         [[0.75944822],
#          [0.70162509],
#          [0.62849584],
#          ...,
#          [0.53798186],
#          [0.38662132],
#          [0.31216931]],
#
#         ...,
#
#         [[0.30933485],
#          [0.33465608],
#          [0.33673469],
#          ...,
#          [0.11696901],
#          [0.10997732],
#          [0.07539683]],
#
#         [[0.33465608],
#          [0.33673469],
#          [0.32785336],
#          ...,
#          [0.10997732],
#          [0.07539683],
#          [0.        ]],
#
#         [[0.33673469],
#          [0.32785336],
#          [0.40117158],
#          ...,
#          [0.07539683],
#          [0.        ],
#          [0.06746032]]]),
#  array([0.38662132, 0.31216931, 0.39814815, 0.36848073, 0.43839758,
#         0.27928949, 0.21371882, 0.21825397, 0.32256236, 0.27059713,
#         0.27362056, 0.33522298, 0.44595616, 0.430839  , 0.42838246,
#         0.47562358, 0.36545729, 0.37981859, 0.42838246, 0.41421013,
#         0.31368103, 0.2095616 , 0.11035525, 0.12698413, 0.17743764,
#         0.07596372, 0.10430839, 0.18575208, 0.17592593, 0.23110355,
#         0.29516251, 0.29516251, 0.2154195 , 0.24924414, 0.20181406,
#         0.24357521, 0.29327286, 0.31897203, 0.38378685, 0.3968254 ,
#         0.35582011, 0.37452759, 0.3675359 , 0.42384732, 0.45597128,
#         0.39739229, 0.47165533, 0.51020408, 0.55385488, 0.53004535,
#         0.5085034 , 0.4829932 , 0.58106576, 0.59164777, 0.68915344,
#         0.67025699, 0.64191232, 0.75755858, 0.75151172, 0.74281935,
#         0.73374906, 0.73469388, 0.81632653, 0.8021542 , 0.87037037,
#         0.8909675 , 0.88794407, 0.91666667, 0.90910809, 0.85941043,
#         0.78476946, 0.77834467, 0.78401361, 0.83125472, 0.7101285 ,
#         0.66780045, 0.62112623, 0.58919123, 0.6031746 , 0.56254724,
#         0.53835979, 0.56538171, 0.53703704, 0.5920257 , 0.70653817,
#         0.52532124, 0.55309902, 0.49754346, 0.46598639, 0.53741497,
#         0.58314437, 0.52305367, 0.50453515, 0.46088435, 0.46730915,
#         0.48601663, 0.44973545, 0.3106576 , 0.2297808 , 0.3100907 ,
#         0.37906274, 0.38473167, 0.36640212, 0.26549509, 0.27173091,
#         0.24452003, 0.2324263 , 0.32029478, 0.23318216, 0.30933485,
#         0.33465608, 0.33673469, 0.32785336, 0.40117158, 0.44236584,
#         0.49697657, 0.44047619, 0.35449735, 0.56122449, 0.51587302,
#         0.46504157, 0.35884354, 0.24263039, 0.23318216, 0.24338624,
#         0.25434618, 0.16685563, 0.393613  , 0.44708995, 0.42025699,
#         0.45351474, 0.42989418, 0.46636432, 0.4771353 , 0.41515495,
#         0.45616024, 0.47297808, 0.4170446 , 0.34353741, 0.28590325,
#         0.41553288, 0.42082389, 0.41137566, 0.38907785, 0.31878307,
#         0.28155707, 0.31386999, 0.30461073, 0.34863946, 0.36715797,
#         0.324452  , 0.19765684, 0.16005291, 0.11961451, 0.11829176,
#         0.17781557, 0.11696901, 0.10997732, 0.07539683, 0.        ,
#         0.06746032, 0.07350718]))

# %% [markdown]
# ## 3. Build LSTM model

# %%
def LSTM_model():
    
    model = Sequential()
    
    model.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1],1)))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 50, return_sequences = True))
    model.add(Dropout(0.2))

    model.add(LSTM(units = 50))
    model.add(Dropout(0.2))
    
    model.add(Dense(units=1))
    
    return model

# %% [markdown]
# ## 4. Training

# %%
model = LSTM_model()
model.summary()
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 50, 50)            10400
#
#  dropout_3 (Dropout)         (None, 50, 50)            0
#
#  lstm_4 (LSTM)               (None, 50, 50)            20200
#
#  dropout_4 (Dropout)         (None, 50, 50)            0
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dropout_5 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath = 'weights_best.hdf5', 
                               verbose = 2, 
                               save_best_only = True,
                               monitor='loss'
                               )

hist = model.fit(x_train, 
          y_train, 
          epochs=35, 
          batch_size = 32,
          callbacks = [checkpointer])
# Out:
# Epoch 1/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0094
# Epoch 1: loss improved from inf to 0.00935, saving model to weights_best.hdf5
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0094
# Epoch 2/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0108
# Epoch 2: loss did not improve from 0.00935
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0109
# Epoch 3/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0115
# Epoch 3: loss did not improve from 0.00935
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0115
# Epoch 4/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0131
# Epoch 4: loss did not improve from 0.00935
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0130
# Epoch 5/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0090
# Epoch 5: loss improved from 0.00935 to 0.00893, saving model to weights_best.hdf5
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0089
# Epoch 6/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0114
# Epoch 6: loss did not improve from 0.00893
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0115
# Epoch 7/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0101
# Epoch 7: loss did not improve from 0.00893
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0101
# Epoch 8/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0078
# Epoch 8: loss improved from 0.00893 to 0.00780, saving model to weights_best.hdf5
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0078
# Epoch 9/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0102
# Epoch 9: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0101
# Epoch 10/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0097
# Epoch 10: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0099
# Epoch 11/35
# 6/6 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 11: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0099
# Epoch 12/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0092
# Epoch 12: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0091
# Epoch 13/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0096
# Epoch 13: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0095
# Epoch 14/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0094
# Epoch 14: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0093
# Epoch 15/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0081
# Epoch 15: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0084
# Epoch 16/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0105
# Epoch 16: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0106
# Epoch 17/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0095
# Epoch 17: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0094
# Epoch 18/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0109
# Epoch 18: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0109
# Epoch 19/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0085
# Epoch 19: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0084
# Epoch 20/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0095
# Epoch 20: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0094
# Epoch 21/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0091
# Epoch 21: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0091
# Epoch 22/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0085
# Epoch 22: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0085
# Epoch 23/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0078
# Epoch 23: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0078
# Epoch 24/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0088
# Epoch 24: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0087
# Epoch 25/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0082
# Epoch 25: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0081
# Epoch 26/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0083
# Epoch 26: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0085
# Epoch 27/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0087
# Epoch 27: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0087
# Epoch 28/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0086
# Epoch 28: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0087
# Epoch 29/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0104
# Epoch 29: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0103
# Epoch 30/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0092
# Epoch 30: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0091
# Epoch 31/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0092
# Epoch 31: loss did not improve from 0.00780
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0092
# Epoch 32/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0073
# Epoch 32: loss improved from 0.00780 to 0.00737, saving model to weights_best.hdf5
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0074
# Epoch 33/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0090
# Epoch 33: loss did not improve from 0.00737
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0090
# Epoch 34/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0083
# Epoch 34: loss did not improve from 0.00737
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0082
# Epoch 35/35
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0084
# Epoch 35: loss did not improve from 0.00737
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0083

# %% [markdown]
# ## 5. Predictions

# %%
# Prepare test dataset (2023 to end)
test_df = close_df['2023-01-01':]
actual_prices = test_df['close'].values

model_inputs = close_df[len(train_df) - N_PRED_DAYS:].values
model_inputs = model_inputs.reshape(-1,1)
model_inputs = scaler.transform(model_inputs)

# %%
x_test = []

for i in range(len(model_inputs) - N_PRED_DAYS):
    x_test.append(model_inputs[i:i+N_PRED_DAYS, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

predicted_prices = model.predict(x_test)
predicted_prices = scaler.inverse_transform(predicted_prices)
# Out:
# 2/2 [==============================] - 1s 12ms/step

# %%
# Plot predicted prices
plt.plot(actual_prices, color='black', label=f"Actual price")
plt.plot(predicted_prices, color= 'green', label=f"predicted price")
plt.title("AAPL share price")
plt.xlabel("time")
plt.ylabel("AAPL share price")
plt.legend()
plt.show()

# %%
# Predict next day
real_data = [model_inputs[len(model_inputs)+1 - N_PRED_DAYS:len(model_inputs+1),0]]
real_data = np.array(real_data)
real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))

prediction = model.predict(real_data)
prediction = scaler.inverse_transform(prediction)
print(f"prediction: {prediction}")
# Out:
# 1/1 [==============================] - 1s 738ms/step
# prediction: [[149.90587]]
